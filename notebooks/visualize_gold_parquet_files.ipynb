# %% [markdown]
# ## Visualice the .parquet files saved in datalake_gold

# %% [markdown]
# Import libraries and declare paths

# %%
from pathlib import Path

GOLD_BASE_PATH = "../datalake_gold"

gold_files = sorted(Path(GOLD_BASE_PATH).rglob("*.parquet"))

for f in gold_files:
    print(f)
# Out:
# ..\datalake_gold\brand_analytics_weekly_20260530_200341.parquet
# ..\datalake_gold\brand_analytics_weekly_20260530_200341.parquet\part-00000-43379565-9528-459f-b217-5c1b36f46f44-c000.snappy.parquet
# ..\datalake_gold\brand_analytics_weekly_20260602_214550.parquet
# ..\datalake_gold\brand_analytics_weekly_20260602_214550.parquet\part-00000-094ca038-27e1-488a-a4a6-68c43dc91248-c000.snappy.parquet
# ..\datalake_gold\governance\news\governance_news_weekly_20260530_200322.parquet
# ..\datalake_gold\governance\news\governance_news_weekly_20260530_200322.parquet\part-00000-d7c4f23f-c4dc-4d3e-aafb-ec844028786c-c000.snappy.parquet
# ..\datalake_gold\governance\news\governance_news_weekly_20260602_214531.parquet
# ..\datalake_gold\governance\tweets\governance_tweets_weekly_20260530_200322.parquet
# ..\datalake_gold\governance\tweets\governance_tweets_weekly_20260530_200322.parquet\part-00000-82734d2b-071b-420a-85a7-8e0943577fef-c000.snappy.parquet
# ..\datalake_gold\governance\tweets\governance_tweets_weekly_20260602_214531.parquet
# ..\datalake_gold\product_analytics_weekly_20260530_200340.parquet
# ..\datalake_gold\product_analytics_weekly_20260530_200340.parquet\part-00000-2c169af2-4c76-4bc1-876a-b325c818dd00-c000.snappy.parquet
# ..\datalake_gold\product_analytics_weekly_20260602_214552.parquet
# ..\datalake_gold\product_analytics_weekly_20260602_214552.parquet\part-00000-fbfbd12d-2029-4da5-b9f9-7d4d712595e0-c000.snappy.parquet
# ..\datalake_gold\representative_comments_weekly_20260530_200340.parquet
# ..\datalake_gold\representative_comments_weekly_20260530_200340.parquet\part-00000-87d5fa96-87ea-4b5a-a256-e84c3a95d8e7-c000.snappy.parquet
# ..\datalake_gold\representative_comments_weekly_20260602_214549.parquet
# ..\datalake_gold\representative_comments_weekly_20260602_214549.parquet\part-00000-31a5d4e0-868b-4b4b-b901-39ac7132fa3a-c000.snappy.parquet
# ..\datalake_gold\storytelling_weekly_20260530_200353.parquet
# ..\datalake_gold\storytelling_weekly_20260530_200353.parquet\part-00000-8182a0b5-63f2-4150-a6eb-0560e01d6af4-c000.snappy.parquet
# ..\datalake_gold\storytelling_weekly_20260602_214605.parquet
# ..\datalake_gold\storytelling_weekly_20260602_214605.parquet\part-00000-38c124eb-ec05-4ad6-b12c-44dcd1aee9e6-c000.snappy.parquet
# ..\datalake_gold\top_influencers_weekly_20260530_200340.parquet
# ..\datalake_gold\top_influencers_weekly_20260530_200340.parquet\part-00000-3c7a06ff-537f-4cee-b58c-5005009f13f9-c000.snappy.parquet
# ..\datalake_gold\top_influencers_weekly_20260602_214550.parquet
# ..\datalake_gold\top_influencers_weekly_20260602_214550.parquet\part-00000-fa05615d-0ae2-4d13-a1a7-a42b676e55e1-c000.snappy.parquet
# ..\datalake_gold\topic_analytics_weekly_20260530_200340.parquet
# ..\datalake_gold\topic_analytics_weekly_20260530_200340.parquet\part-00000-bbef263d-5cb6-4a45-91ae-bc005b5d85eb-c000.snappy.parquet
# ..\datalake_gold\topic_analytics_weekly_20260602_214552.parquet
# ..\datalake_gold\topic_analytics_weekly_20260602_214552.parquet\part-00000-d90be666-7edf-4f75-9751-e5c4d2ec8275-c000.snappy.parquet

# %% [markdown]
# ---

# %%
from pathlib import Path
import pandas as pd

GOLD_PATH = Path("../datalake_gold")

datasets = [
    p for p in GOLD_PATH.rglob("*.parquet")
    if p.is_dir()
]

print(f"Datasets encontrados: {len(datasets)}")

for dataset in datasets:
    print("\n" + "=" * 120)
    print(dataset.relative_to(GOLD_PATH))

    df = pd.read_parquet(dataset)

    print(f"Rows: {len(df)}")
    print(f"Columns: {len(df.columns)}")

    display(df.head())
# Out:
# Datasets encontrados: 16
#
# ========================================================================================================================
# brand_analytics_weekly_20260530_200341.parquet
# Rows: 23
# Columns: 10
#    week    brand  mentions_twitter  mentions_news  total_mentions  \
# 0    22    apple                18             19              37
# 1    22  samsung                 4             15              19
# 2    22       hp                 5              0               5
# 3    22     sony                 1              4               5
# 4    22   xiaomi                 2              2               4
#
#    total_engagement  positive_pct  negative_pct  neutral_pct  avg_score
# 0              3886          73.0          10.8         16.2     0.5179
# 1                 9          68.4          21.1         10.5     0.5430
# 2                53         100.0           0.0          0.0     0.2958
# 3                 0          40.0          20.0         40.0     0.2652
# 4                 1          75.0          25.0          0.0     0.5705
# ========================================================================================================================
# brand_analytics_weekly_20260602_214550.parquet
# Rows: 15
# Columns: 10
#    week    brand  mentions_twitter  mentions_news  total_mentions  \
# 0    23    apple                60             28              88
# 1    23   google                 0             32              32
# 2    23   xiaomi                 2             30              32
# 3    23  samsung                 2              8              10
# 4    23   nvidia                 6              0               6
#
#    total_engagement  positive_pct  negative_pct  neutral_pct  avg_score
# 0               690          75.0          11.4         13.6     0.4965
# 1                 0          37.5          50.0         12.5     0.4648
# 2                 0          68.8          12.5         18.8     0.4080
# 3               258          40.0           0.0         60.0     0.2570
# 4                 4          33.3           0.0         66.7     0.1953
# ========================================================================================================================
# product_analytics_weekly_20260530_200340.parquet
# Rows: 9
# Columns: 8
#    week     product    brand  mentions  positive_pct  negative_pct  \
# 0    22      iphone    apple        30          76.7          13.3
# 1    22  headphones     None         7          57.1          28.6
# 2    22     earbuds     sony         7          71.4          28.6
# 3    22      galaxy  samsung         5         100.0           0.0
# 4    22     macbook    apple         4          50.0           0.0
#
#    neutral_pct  avg_score
# 0         10.0     0.5404
# 1         14.3     0.5580
# 2          0.0     0.4553
# 3          0.0     0.6704
# 4         50.0     0.4111
# ========================================================================================================================
# product_analytics_weekly_20260602_214552.parquet
# Rows: 9
# Columns: 8
#    week     product    brand  mentions  positive_pct  negative_pct  \
# 0    23      iphone    apple        42          66.7           9.5
# 1    23     macbook    apple        18          88.9          11.1
# 2    23  headphones     bose        16          50.0          50.0
# 3    23      galaxy  samsung        10          40.0           0.0
# 4    23     earbuds      jbl        10          80.0          20.0
#
#    neutral_pct  avg_score
# 0         23.8     0.4395
# 1          0.0     0.4833
# 2          0.0     0.5162
# 3         60.0     0.2570
# 4          0.0     0.6172
# ========================================================================================================================
# representative_comments_weekly_20260530_200340.parquet
# Rows: 23
# Columns: 4
#    week    brand                                       best_comment  \
# 0    22     bose  1/ Really disappointed with Bose ending cloud ...
# 1    22     sony  Ever forget you’re wearing earbuds until the b...
# 2    22  samsung  I've been using these Galaxy Buds FE since Feb...
# 3    22   garmin                                               None
# 4    22      jbl  Big buyer's remorse on the the choice of color...
#
#                                        worst_comment
# 0                                               None
# 1  AnonD-140756, 29 Apr 2013why ddnt anyone menti...
# 2  Ppl writing stories here. Samsung accepted s4 ...
# 3  When my Garmin watch falls off at night and ha...
# 4                                               None
# ========================================================================================================================
# representative_comments_weekly_20260602_214549.parquet
# Rows: 15
# Columns: 4
#    week  brand                                       best_comment  \
# 0    23   bose  The home battery lock-in you don’t (yet) know ...
# 1    23   sony                                               None
# 2    23  apple  The 17T is literally a Poco X8 Pro with the on...
# 3    23     hp  Unironically, I think buying an Xbox Series S ...
# 4    23   asus  A gold-plated gaming mouse? In this economy? I...
#
#                                        worst_comment
# 0  i was so exhausted when i got home yesterday t...
# 1  I would prefer JBL Flip 7 or Sony Ult Field 1 ...
# 2  Anonymous, 31 May 2026I, as an Apple user, do ...
# 3                                               None
# 4                                               None
# ========================================================================================================================
# storytelling_weekly_20260530_200353.parquet
# Rows: 1
# Columns: 10
#    week                                  executive_summary top_brand  \
# 0    22  Apple fue la marca más mencionada durante la s...     apple
#
#   best_brand worst_brand                           brand_sentiment_snapshot  \
# 0         hp         msi  [{"brand": "apple", "total_mentions": 37, "pos...
#
#                         top_positive_topics          top_negative_topics  \
# 0  ["performance", "smartwatch", "battery"]  ["charging", "audio", "ai"]
#
#                                         top_products  \
# 0  ["iphone", "headphones", "earbuds", "galaxy", ...
#
#                              representative_comments
# 0  [{"brand": "bose", "best_comment": "1/ Really ...
# ========================================================================================================================
# storytelling_weekly_20260602_214605.parquet
# Rows: 1
# Columns: 10
#    week                                  executive_summary top_brand  \
# 0    23  Apple fue la marca más mencionada durante la s...     apple
#
#   best_brand worst_brand                           brand_sentiment_snapshot  \
# 0       asus        dell  [{"brand": "apple", "total_mentions": 88, "pos...
#
#                    top_positive_topics                 top_negative_topics  \
# 0  ["battery", "performance", "price"]  ["charging", "connectivity", "ev"]
#
#                                         top_products  \
# 0  ["iphone", "macbook", "headphones", "galaxy", ...
#
#                              representative_comments
# 0  [{"brand": "bose", "best_comment": "The home b...
# ========================================================================================================================
# topic_analytics_weekly_20260530_200340.parquet
# Rows: 13
# Columns: 7
#    week        topic  mentions  positive_pct  negative_pct  neutral_pct  \
# 0    22      display        42          66.7          14.3         19.0
# 1    22     software        22          72.7          22.7          4.5
# 2    22       camera        19          52.6          36.8         10.5
# 3    22  performance        16         100.0           0.0          0.0
# 4    22      battery        15          73.3          20.0          6.7
#
#    avg_score
# 0     0.5293
# 1     0.5403
# 2     0.5913
# 3     0.6065
# 4     0.5807
# ========================================================================================================================
# topic_analytics_weekly_20260602_214552.parquet
# Rows: 12
# Columns: 7
#    week     topic  mentions  positive_pct  negative_pct  neutral_pct  \
# 0    23  software       118          54.2          27.1         18.6
# 1    23   battery        34          88.2          11.8          0.0
# 2    23    camera        26          53.8          23.1         23.1
# 3    23     audio        22          54.5          18.2         27.3
# 4    23   display        16          50.0          25.0         25.0
#
#    avg_score
# 0     0.4479
# 1     0.6435
# 2     0.5357
# 3     0.3811
# 4     0.4062
# ========================================================================================================================
# top_influencers_weekly_20260530_200340.parquet
# Rows: 20
# Columns: 7
#      brand  author_userName  followers  engagement  tweet_count sentiment  \
# 0    apple       SnazzyLabs     295464        2095            1  positive
# 1    apple    queenbeth____      19354        1704            1  positive
# 2   fitbit       DurvidImel      76329        1363            1  positive
# 3   google  pixeluibygoogle      10008         247            1  positive
# 4  oneplus          imDev02      13948          99            1  positive
#
#    week
# 0    22
# 1    22
# 2    22
# 3    22
# 4    22
# ========================================================================================================================
# top_influencers_weekly_20260602_214550.parquet
# Rows: 20
# Columns: 7
#      brand author_userName  followers  engagement  tweet_count sentiment  week
# 0    apple      heyjames01        133         466            2  positive    23
# 1  samsung   openshutter21      32897         258            2  positive    23
# 2    apple    MehakdeepK81        220          54            2  positive    23
# 3    apple        xrihxrih        299          54            2  positive    23
# 4    apple    Emmy_Crrypto      32281          32            2  positive    23
# ========================================================================================================================
# governance\news\governance_news_weekly_20260530_200322.parquet
# Rows: 119
# Columns: 9
#                                             newsLink    date_day  week  \
# 0  https://www.gsmarena.com/xiaomi_unveils_smart_...  2026-05-29    22
# 1  https://www.gsmarena.com/xiaomi_unveils_smart_...  2026-05-29    22
# 2  https://www.gsmarena.com/xiaomi_unveils_smart_...  2026-05-29    22
# 3  https://www.gsmarena.com/xiaomi_unveils_smart_...  2026-05-29    22
# 4  https://www.gsmarena.com/xiaomi_unveils_smart_...  2026-05-29    22
#
#                                         comment_text    brand  product  \
# 0  I like how at least some still make earbuds wi...  samsung   galaxy
# 1  is it still qualified as a smart "band"? it's ...   xiaomi     None
# 2  Hamad1993, 28 May 2026So this one or huwaei ba...   huawei     None
# 3  dexterouz, 28 May 2026For that, I'm waiting fo...     None     None
# 4  Anonymous, 28 May 2026Earbuds without eartips ...     None  earbuds
#
#          topic sentiment  sentiment_score
# 0  performance  positive           0.4609
# 1   smartwatch  positive           0.4588
# 2           ai  positive           0.7184
# 3           ai  positive           0.7778
# 4         None  positive           0.2582
# ========================================================================================================================
# governance\news\governance_news_weekly_20260602_214531.parquet
# Rows: 0
# Columns: 0
# Empty DataFrame
# Columns: []
# Index: []
# ========================================================================================================================
# governance\tweets\governance_tweets_weekly_20260530_200322.parquet
# Rows: 60
# Columns: 18
#               tweet_id    date_day  week author_userName  author_followers  \
# 0  2060004476669374743  2026-05-28    22  SouthernFreeez               315
# 1  2059950505447584179  2026-05-28    22  oluwafemi10591              4126
# 2  2059950392176234910  2026-05-28    22  oluwafemi10591              4126
# 3  2059937735977398654  2026-05-28    22      GearReview              4058
# 4  2059914754030776460  2026-05-28    22        CDLHater             26352
#
#                                                 text lang  total_engagement  \
# 0  1/ Really disappointed with Bose ending cloud ...   en                 1
# 1  I got into a screaming match on the bus this m...   en                 1
# 2  I got into a screaming match on the bus this m...   en                 1
# 3  Ever forget you’re wearing earbuds until the b...   en                 0
# 4  Dashy talks about Mercules' camera falling on ...   en               395
#
#    likeCount  replyCount  retweetCount  quoteCount brand     product  \
# 0          0           1             0           0  bose        None
# 1          1           0             0           0  None  headphones
# 2          1           0             0           0  None  headphones
# 3          0           0             0           0  sony     earbuds
# 4        391           0             4           0  None     earbuds
#
#       topic sentiment  sentiment_score      experience_type
# 0  software  positive           0.2975  personal_experience
# 1    camera  negative           0.9787  personal_experience
# 2    camera  negative           0.9787  personal_experience
# 3   battery  positive           0.4329  personal_experience
# 4    camera  negative           0.1406  personal_experience
# ========================================================================================================================
# governance\tweets\governance_tweets_weekly_20260602_214531.parquet
# Rows: 0
# Columns: 0
# Empty DataFrame
# Columns: []
# Index: []
